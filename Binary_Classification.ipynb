# %% [markdown]
# <a href="https://colab.research.google.com/github/evanstaffen/Melanoma-Identification-with-Convolutinal-Neural-Networks/blob/main/Binary_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Binary Classification Modeling

# %% [markdown]
# ## Imports and functions

# %%
from sklearn.metrics import plot_confusion_matrix
from tensorflow.math import confusion_matrix
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
from tensorflow.keras.utils import img_to_array,load_img
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.metrics import Recall as Recall
from tensorflow.keras.wrappers import scikit_learn
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam, SGD
from keras import models, layers, optimizers
from tensorflow.keras.wrappers import scikit_learn
from keras.callbacks import EarlyStopping
import os
import shutil
import pickle

# %% [markdown]
# ## Reading in Photos

# %%
#Use this function as a sanity check
count = 0
dif_files = ['Training_Photos/NV','Testing_Photos/NV','Validation_Photos/NV','Training_Photos/MEL','Testing_Photos/MEL','Validation_Photos/MEL']
for dif in dif_files:
  for root_dir, cur_dir, files in os.walk(f'/content/drive/MyDrive/Melanoma_Mole/{dif}'):
    count += len(files)
    print(dif, 'file count:', count)
    count = 0
# Out:
# Training_Photos/NV file count: 6291
# Testing_Photos/NV file count: 2480
# Validation_Photos/NV file count: 1024
# Training_Photos/MEL file count: 3259
# Testing_Photos/MEL file count: 905
# Validation_Photos/MEL file count: 358

# %%
datagen = ImageDataGenerator(rescale= 1./255,
                             zca_whitening=True
                            )
                               
                               

training_generator = datagen.flow_from_directory(
    '/content/drive/MyDrive/Melanoma_Mole/Training_Photos',
    target_size=(100, 100),
    batch_size=955,
    color_mode = 'rgb',
    class_mode='categorical'
    )
                               
validation_generator = datagen.flow_from_directory(
    '/content/drive/MyDrive/Melanoma_Mole/Validation_Photos',
    target_size=(100, 100),
    batch_size=138,
    color_mode = 'rgb',
    class_mode='categorical'
    )

testing_generator = datagen.flow_from_directory(
    '/content/drive/MyDrive/Melanoma_Mole/Testing_Photos',
    target_size=(100, 100),
    batch_size=338,
    color_mode = 'rgb',
   class_mode='categorical'
   )
# Out:
# /usr/local/lib/python3.8/dist-packages/keras/preprocessing/image.py:1285: UserWarning: This ImageDataGenerator specifies `zca_whitening`, which overrides setting of `featurewise_center`.
#   warnings.warn('This ImageDataGenerator specifies '
# Found 9550 images belonging to 2 classes.
# Found 1382 images belonging to 2 classes.
# Found 3385 images belonging to 2 classes.

# %%
train_images, train_labels = next(training_generator)
val_images, val_labels = next(validation_generator)
test_images, test_labels = next(testing_generator)
# Out:
# /usr/local/lib/python3.8/dist-packages/keras/preprocessing/image.py:1663: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.8/dist-packages/keras/preprocessing/image.py:1682: UserWarning: This ImageDataGenerator specifies `zca_whitening`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '

# %%
#Saving image arrays
with open(f'/content/drive/MyDrive/Melanoma_Mole/Arrays/train_images_arrays.npy', 'wb') as f:
  np.save(f, train_images)
with open(f'/content/drive/MyDrive/Melanoma_Mole/Arrays/val_images_arrays.npy', 'wb') as f:
  np.save(f, val_images)
with open(f'/content/drive/MyDrive/Melanoma_Mole/Arrays/test_images_arrays.npy', 'wb') as f:
  np.save(f, test_images)

#Saving label arrays
with open('/content/drive/MyDrive/Melanoma_Mole/Arrays/train_label_arrays.npy', 'wb') as f:
  np.save(f, train_labels)
with open('/content/drive/MyDrive/Melanoma_Mole/Arrays/val_label_arrays.npy', 'wb') as f:
  np.save(f, val_labels)
with open('/content/drive/MyDrive/Melanoma_Mole/Arrays/test_label_arrays.npy', 'wb') as f:
  np.save(f, test_labels)

# %%
# Reshape label arrays for modelling
train_y = np.reshape(train_labels[:,0], (955,1))
test_y = np.reshape(test_labels[:,0], (338,1))
val_y = np.reshape(val_labels[:,0], (138,1))

# %% [markdown]
# # First Model

# %%
# Instantiate Sequential
first_model = models.Sequential()

# Input Layer
# Consider changes number of nodes, input_shape and activation
# 64 filters, 3*3 square each stride, max pooling into 2*2 matrix
first_model.add(layers.Conv2D(64, (3,3), input_shape = (100,100,3), activation = 'relu'))
first_model.add(layers.MaxPooling2D(2,2))

# Dense Layers
first_model.add(layers.Flatten())
first_model.add(layers.Dense(64,activation='relu'))

# Output Layer
first_model.add(layers.Dense(1, activation='sigmoid'))

# Compile
# optimizer
first_model.compile(optimizer='adam',
                    loss='binary_crossentropy',
                    metrics=[Recall(),'acc'])

# Early Stopping
early_stop = EarlyStopping(monitor='acc', min_delta=1e-8,
                           verbose=1, patience=10,
                           mode='max')
# Summary
first_model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 98, 98, 64)        1792
#
#  max_pooling2d_15 (MaxPoolin  (None, 49, 49, 64)       0
#  g2D)
#
#  flatten_12 (Flatten)        (None, 153664)            0
#
#  dense_26 (Dense)            (None, 64)                9834560
#
#  dense_27 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 9,836,417
# Trainable params: 9,836,417
# Non-trainable params: 0
# _________________________________________________________________

# %%
results_1 = first_model.fit(train_images, 
                    train_y,
                    epochs=200, verbose=1, 
                    validation_data=(val_images,val_y),
                    callbacks=early_stop)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.

# %%
first_model.save('/content/drive/MyDrive/Melanoma_Mole/Models/first_model_tf',save_format='tf')

# %%
history_1 = results_1.history 
plt.figure() 
plt.plot(history_1['val_loss']) 
plt.plot(history_1['loss']) 
plt.legend(['val_loss', 'loss']) 
plt.title('Loss') 
plt.xlabel('Epochs') 
plt.ylabel('Loss')
plt.show()
  
plt.figure()
plt.plot(history_1['val_recall_9'])
plt.plot(history_1['recall_9'])
plt.legend(['Validation Recall','Recall'])
plt.title('Recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.show()

plt.figure()
plt.plot(history_1['val_acc'])
plt.plot(history_1['acc'])
plt.legend(['val_acc', 'acc'])
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()

# %%
first_model.evaluate(test_images,test_y)
# Out:
# 11/11 [==============================] - 2s 115ms/step - loss: 0.6584 - recall_12: 0.0825 - acc: 0.7160
# [0.6583541631698608, 0.0824742242693901, 0.715976357460022]

# %% [markdown]
# # Second Model

# %%
# Instantiate Sequential
second_model = models.Sequential()

# Input Layer
# Consider changes number of nodes, input_shape and activation
# 64 filters, 3*3 square each stride, max pooling into 2*2 matrix
second_model.add(layers.Conv2D(128, (3,3), input_shape = (100,100,3), activation = 'relu'))
second_model.add(layers.MaxPooling2D(2,2))
second_model.add(layers.Dropout(0.3))

#Hidden Layer
second_model.add(layers.Conv2D(64, (3,3), input_shape = (100,100,3), activation = 'relu'))
second_model.add(layers.MaxPooling2D(2,2))
second_model.add(layers.Dropout(0.3))

# Dense Layers
second_model.add(layers.Flatten())
second_model.add(layers.Dense(64,activation='relu'))

second_model.add(layers.Dense(32,activation='relu'))

# Output Layer
second_model.add(layers.Dense(1, activation='sigmoid'))

# Compile
# optimizer
second_model.compile(optimizer='adam',
                    loss='binary_crossentropy',
                    metrics=[Recall(),'acc'])

# Summary
second_model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_13 (Conv2D)          (None, 98, 98, 128)       3584
#
#  max_pooling2d_13 (MaxPoolin  (None, 49, 49, 128)      0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 49, 49, 128)       0
#
#  conv2d_14 (Conv2D)          (None, 47, 47, 64)        73792
#
#  max_pooling2d_14 (MaxPoolin  (None, 23, 23, 64)       0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 23, 23, 64)        0
#
#  flatten_11 (Flatten)        (None, 33856)             0
#
#  dense_23 (Dense)            (None, 64)                2166848
#
#  dense_24 (Dense)            (None, 32)                2080
#
#  dense_25 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 2,246,337
# Trainable params: 2,246,337
# Non-trainable params: 0
# _________________________________________________________________

# %%
results_2 = second_model.fit(train_images, 
                    train_y,
                    epochs=200, verbose=1, 
                    validation_data=(val_images,val_y),
                    callbacks=early_stop)
# Out:
# Epoch 1/200
# 30/30 [==============================] - 50s 2s/step - loss: 0.7129 - recall_11: 0.0000e+00 - acc: 0.6681 - val_loss: 0.5440 - val_recall_11: 0.0000e+00 - val_acc: 0.7971
# Epoch 2/200
# 30/30 [==============================] - 46s 2s/step - loss: 0.6108 - recall_11: 0.0032 - acc: 0.6681 - val_loss: 0.5944 - val_recall_11: 0.2500 - val_acc: 0.7971
# Epoch 3/200
# 30/30 [==============================] - 45s 2s/step - loss: 0.6193 - recall_11: 0.1073 - acc: 0.6743 - val_loss: 0.4991 - val_recall_11: 0.2500 - val_acc: 0.7971
# Epoch 4/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.6168 - recall_11: 0.2555 - acc: 0.6764 - val_loss: 0.5630 - val_recall_11: 0.2500 - val_acc: 0.8043
# Epoch 5/200
# 30/30 [==============================] - 45s 2s/step - loss: 0.5999 - recall_11: 0.1199 - acc: 0.6723 - val_loss: 0.5435 - val_recall_11: 0.3929 - val_acc: 0.7826
# Epoch 6/200
# 30/30 [==============================] - 48s 2s/step - loss: 0.5780 - recall_11: 0.2555 - acc: 0.6942 - val_loss: 0.4892 - val_recall_11: 0.4286 - val_acc: 0.7681
# Epoch 7/200
# 30/30 [==============================] - 46s 2s/step - loss: 0.5622 - recall_11: 0.3912 - acc: 0.6984 - val_loss: 0.5658 - val_recall_11: 0.5357 - val_acc: 0.6594
# Epoch 8/200
# 30/30 [==============================] - 48s 2s/step - loss: 0.5635 - recall_11: 0.4006 - acc: 0.7089 - val_loss: 0.4696 - val_recall_11: 0.3929 - val_acc: 0.7609
# Epoch 9/200
# 30/30 [==============================] - 46s 2s/step - loss: 0.5536 - recall_11: 0.3975 - acc: 0.7047 - val_loss: 0.6074 - val_recall_11: 0.5000 - val_acc: 0.6449
# Epoch 10/200
# 30/30 [==============================] - 48s 2s/step - loss: 0.5370 - recall_11: 0.4101 - acc: 0.7162 - val_loss: 0.4706 - val_recall_11: 0.4286 - val_acc: 0.7681
# Epoch 11/200
# 30/30 [==============================] - 46s 2s/step - loss: 0.5450 - recall_11: 0.4196 - acc: 0.7340 - val_loss: 0.4911 - val_recall_11: 0.3214 - val_acc: 0.7826
# Epoch 12/200
# 30/30 [==============================] - 46s 2s/step - loss: 0.5247 - recall_11: 0.3975 - acc: 0.7298 - val_loss: 0.5095 - val_recall_11: 0.3571 - val_acc: 0.7681
# Epoch 13/200
# 30/30 [==============================] - 48s 2s/step - loss: 0.5263 - recall_11: 0.3975 - acc: 0.7372 - val_loss: 0.4781 - val_recall_11: 0.4643 - val_acc: 0.7681
# Epoch 14/200
# 30/30 [==============================] - 46s 2s/step - loss: 0.5081 - recall_11: 0.4132 - acc: 0.7393 - val_loss: 0.4986 - val_recall_11: 0.3929 - val_acc: 0.7536
# Epoch 15/200
# 30/30 [==============================] - 49s 2s/step - loss: 0.5024 - recall_11: 0.4511 - acc: 0.7497 - val_loss: 0.4788 - val_recall_11: 0.5357 - val_acc: 0.7391
# Epoch 16/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.4748 - recall_11: 0.4826 - acc: 0.7623 - val_loss: 0.4446 - val_recall_11: 0.2857 - val_acc: 0.7971
# Epoch 17/200
# 30/30 [==============================] - 48s 2s/step - loss: 0.4783 - recall_11: 0.4763 - acc: 0.7560 - val_loss: 0.4771 - val_recall_11: 0.2500 - val_acc: 0.7536
# Epoch 18/200
# 30/30 [==============================] - 46s 2s/step - loss: 0.4882 - recall_11: 0.4385 - acc: 0.7571 - val_loss: 0.4620 - val_recall_11: 0.4286 - val_acc: 0.7681
# Epoch 19/200
# 30/30 [==============================] - 48s 2s/step - loss: 0.4780 - recall_11: 0.4543 - acc: 0.7560 - val_loss: 0.5277 - val_recall_11: 0.4643 - val_acc: 0.7609
# Epoch 20/200
# 30/30 [==============================] - 46s 2s/step - loss: 0.5103 - recall_11: 0.4259 - acc: 0.7581 - val_loss: 0.4378 - val_recall_11: 0.2500 - val_acc: 0.7681
# Epoch 21/200
# 30/30 [==============================] - 45s 2s/step - loss: 0.4983 - recall_11: 0.4574 - acc: 0.7550 - val_loss: 0.5425 - val_recall_11: 0.5000 - val_acc: 0.7319
# Epoch 22/200
# 30/30 [==============================] - 48s 2s/step - loss: 0.4304 - recall_11: 0.5615 - acc: 0.7969 - val_loss: 0.4354 - val_recall_11: 0.4286 - val_acc: 0.7971
# Epoch 23/200
# 30/30 [==============================] - 46s 2s/step - loss: 0.4299 - recall_11: 0.5457 - acc: 0.7874 - val_loss: 0.4705 - val_recall_11: 0.3571 - val_acc: 0.7899
# Epoch 24/200
# 30/30 [==============================] - 48s 2s/step - loss: 0.4190 - recall_11: 0.5678 - acc: 0.8031 - val_loss: 0.4748 - val_recall_11: 0.4286 - val_acc: 0.7174
# Epoch 25/200
# 30/30 [==============================] - 46s 2s/step - loss: 0.4082 - recall_11: 0.6088 - acc: 0.7979 - val_loss: 0.4370 - val_recall_11: 0.3214 - val_acc: 0.7826
# Epoch 26/200
# 30/30 [==============================] - 48s 2s/step - loss: 0.4112 - recall_11: 0.5647 - acc: 0.8052 - val_loss: 0.5078 - val_recall_11: 0.4643 - val_acc: 0.7391
# Epoch 27/200
# 30/30 [==============================] - 46s 2s/step - loss: 0.4164 - recall_11: 0.5584 - acc: 0.7958 - val_loss: 0.4732 - val_recall_11: 0.4286 - val_acc: 0.7464
# Epoch 28/200
# 30/30 [==============================] - 48s 2s/step - loss: 0.4125 - recall_11: 0.6088 - acc: 0.8209 - val_loss: 0.5441 - val_recall_11: 0.4286 - val_acc: 0.7101
# Epoch 29/200
# 30/30 [==============================] - 45s 2s/step - loss: 0.4040 - recall_11: 0.6025 - acc: 0.8178 - val_loss: 0.5055 - val_recall_11: 0.4286 - val_acc: 0.7246
# Epoch 30/200
# 30/30 [==============================] - 46s 2s/step - loss: 0.3703 - recall_11: 0.6435 - acc: 0.8304 - val_loss: 0.4899 - val_recall_11: 0.4643 - val_acc: 0.7319
# Epoch 31/200
# 30/30 [==============================] - 48s 2s/step - loss: 0.3544 - recall_11: 0.6215 - acc: 0.8356 - val_loss: 0.5915 - val_recall_11: 0.6429 - val_acc: 0.6884
# Epoch 32/200
# 30/30 [==============================] - 48s 2s/step - loss: 0.3460 - recall_11: 0.6751 - acc: 0.8408 - val_loss: 0.4912 - val_recall_11: 0.3929 - val_acc: 0.7754
# Epoch 33/200
# 30/30 [==============================] - 46s 2s/step - loss: 0.3275 - recall_11: 0.7003 - acc: 0.8545 - val_loss: 0.5203 - val_recall_11: 0.3929 - val_acc: 0.7536
# Epoch 34/200
# 30/30 [==============================] - 46s 2s/step - loss: 0.3322 - recall_11: 0.6719 - acc: 0.8429 - val_loss: 0.5900 - val_recall_11: 0.5357 - val_acc: 0.6594
# Epoch 35/200
# 30/30 [==============================] - 48s 2s/step - loss: 0.4158 - recall_11: 0.6562 - acc: 0.8000 - val_loss: 0.4947 - val_recall_11: 0.3929 - val_acc: 0.7536
# Epoch 36/200
# 30/30 [==============================] - 45s 2s/step - loss: 0.3869 - recall_11: 0.5931 - acc: 0.8241 - val_loss: 0.5819 - val_recall_11: 0.3929 - val_acc: 0.7174
# Epoch 37/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.3313 - recall_11: 0.6782 - acc: 0.8503 - val_loss: 0.5062 - val_recall_11: 0.4643 - val_acc: 0.7464
# Epoch 38/200
# 30/30 [==============================] - 45s 2s/step - loss: 0.3286 - recall_11: 0.6814 - acc: 0.8513 - val_loss: 0.6690 - val_recall_11: 0.5357 - val_acc: 0.7174
# Epoch 39/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.2923 - recall_11: 0.7098 - acc: 0.8785 - val_loss: 0.6189 - val_recall_11: 0.3929 - val_acc: 0.7174
# Epoch 40/200
# 30/30 [==============================] - 46s 2s/step - loss: 0.3050 - recall_11: 0.7192 - acc: 0.8681 - val_loss: 0.4972 - val_recall_11: 0.3929 - val_acc: 0.7754
# Epoch 41/200
# 30/30 [==============================] - 48s 2s/step - loss: 0.3030 - recall_11: 0.7413 - acc: 0.8806 - val_loss: 0.5420 - val_recall_11: 0.5000 - val_acc: 0.7391
# Epoch 42/200
# 30/30 [==============================] - 46s 2s/step - loss: 0.2784 - recall_11: 0.7445 - acc: 0.8754 - val_loss: 0.5770 - val_recall_11: 0.4643 - val_acc: 0.7464
# Epoch 43/200
# 30/30 [==============================] - 46s 2s/step - loss: 0.2705 - recall_11: 0.7224 - acc: 0.8723 - val_loss: 0.6899 - val_recall_11: 0.5000 - val_acc: 0.7029
# Epoch 44/200
# 30/30 [==============================] - 48s 2s/step - loss: 0.2383 - recall_11: 0.7729 - acc: 0.8974 - val_loss: 0.7314 - val_recall_11: 0.5714 - val_acc: 0.7391
# Epoch 45/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.2121 - recall_11: 0.8013 - acc: 0.9099 - val_loss: 0.8755 - val_recall_11: 0.5000 - val_acc: 0.7029
# Epoch 46/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.2458 - recall_11: 0.7950 - acc: 0.9037 - val_loss: 0.7375 - val_recall_11: 0.5357 - val_acc: 0.7536
# Epoch 47/200
# 30/30 [==============================] - 46s 2s/step - loss: 0.2141 - recall_11: 0.8202 - acc: 0.9215 - val_loss: 0.8844 - val_recall_11: 0.5000 - val_acc: 0.7029
# Epoch 48/200
# 30/30 [==============================] - 48s 2s/step - loss: 0.2130 - recall_11: 0.8328 - acc: 0.9141 - val_loss: 0.6688 - val_recall_11: 0.4643 - val_acc: 0.7391
# Epoch 49/200
# 30/30 [==============================] - 46s 2s/step - loss: 0.2622 - recall_11: 0.7886 - acc: 0.8995 - val_loss: 0.6384 - val_recall_11: 0.3571 - val_acc: 0.7246
# Epoch 50/200
# 30/30 [==============================] - 48s 2s/step - loss: 0.2122 - recall_11: 0.8328 - acc: 0.9141 - val_loss: 0.8268 - val_recall_11: 0.4286 - val_acc: 0.7319
# Epoch 51/200
# 30/30 [==============================] - 46s 2s/step - loss: 0.2214 - recall_11: 0.8233 - acc: 0.9173 - val_loss: 0.8379 - val_recall_11: 0.4286 - val_acc: 0.7101
# Epoch 52/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.1804 - recall_11: 0.8139 - acc: 0.9194 - val_loss: 0.8461 - val_recall_11: 0.4643 - val_acc: 0.7101
# Epoch 53/200
# 30/30 [==============================] - 45s 2s/step - loss: 0.1611 - recall_11: 0.8864 - acc: 0.9455 - val_loss: 0.8132 - val_recall_11: 0.5714 - val_acc: 0.7464
# Epoch 54/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.1680 - recall_11: 0.8707 - acc: 0.9382 - val_loss: 1.0406 - val_recall_11: 0.5000 - val_acc: 0.6884
# Epoch 55/200
# 30/30 [==============================] - 46s 2s/step - loss: 0.1675 - recall_11: 0.8801 - acc: 0.9351 - val_loss: 0.8256 - val_recall_11: 0.5357 - val_acc: 0.7464
# Epoch 56/200
# 30/30 [==============================] - 45s 2s/step - loss: 0.1473 - recall_11: 0.8864 - acc: 0.9414 - val_loss: 1.1079 - val_recall_11: 0.6071 - val_acc: 0.6812
# Epoch 57/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.1390 - recall_11: 0.9022 - acc: 0.9560 - val_loss: 0.8697 - val_recall_11: 0.5000 - val_acc: 0.7754
# Epoch 58/200
# 30/30 [==============================] - 45s 1s/step - loss: 0.1554 - recall_11: 0.8833 - acc: 0.9435 - val_loss: 1.0621 - val_recall_11: 0.7500 - val_acc: 0.7029
# Epoch 59/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.2212 - recall_11: 0.8297 - acc: 0.9131 - val_loss: 0.9017 - val_recall_11: 0.5714 - val_acc: 0.7246
# Epoch 60/200
# 30/30 [==============================] - 46s 2s/step - loss: 0.1509 - recall_11: 0.9148 - acc: 0.9508 - val_loss: 0.7880 - val_recall_11: 0.6071 - val_acc: 0.7464
# Epoch 61/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.1185 - recall_11: 0.8927 - acc: 0.9487 - val_loss: 1.1955 - val_recall_11: 0.6429 - val_acc: 0.6522
# Epoch 62/200
# 30/30 [==============================] - 45s 2s/step - loss: 0.1132 - recall_11: 0.9085 - acc: 0.9550 - val_loss: 1.0577 - val_recall_11: 0.6071 - val_acc: 0.7101
# Epoch 63/200
# 30/30 [==============================] - 48s 2s/step - loss: 0.1115 - recall_11: 0.9148 - acc: 0.9581 - val_loss: 0.9751 - val_recall_11: 0.5714 - val_acc: 0.7246
# Epoch 64/200
# 30/30 [==============================] - 45s 2s/step - loss: 0.1923 - recall_11: 0.8833 - acc: 0.9267 - val_loss: 1.0336 - val_recall_11: 0.4643 - val_acc: 0.6884
# Epoch 65/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.1414 - recall_11: 0.8864 - acc: 0.9497 - val_loss: 0.8931 - val_recall_11: 0.5357 - val_acc: 0.7609
# Epoch 66/200
# 30/30 [==============================] - 45s 2s/step - loss: 0.1075 - recall_11: 0.9306 - acc: 0.9623 - val_loss: 0.9879 - val_recall_11: 0.4286 - val_acc: 0.7174
# Epoch 67/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.0867 - recall_11: 0.9338 - acc: 0.9696 - val_loss: 1.2308 - val_recall_11: 0.4643 - val_acc: 0.6884
# Epoch 68/200
# 30/30 [==============================] - 45s 2s/step - loss: 0.0947 - recall_11: 0.9306 - acc: 0.9623 - val_loss: 1.0483 - val_recall_11: 0.4286 - val_acc: 0.7609
# Epoch 69/200
# 30/30 [==============================] - 46s 2s/step - loss: 0.1670 - recall_11: 0.8770 - acc: 0.9372 - val_loss: 1.0638 - val_recall_11: 0.5714 - val_acc: 0.7391
# Epoch 70/200
# 30/30 [==============================] - 46s 2s/step - loss: 0.1561 - recall_11: 0.9022 - acc: 0.9435 - val_loss: 0.8646 - val_recall_11: 0.4286 - val_acc: 0.7536
# Epoch 71/200
# 30/30 [==============================] - 45s 2s/step - loss: 0.1432 - recall_11: 0.9148 - acc: 0.9487 - val_loss: 1.0131 - val_recall_11: 0.5000 - val_acc: 0.7609
# Epoch 72/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.1967 - recall_11: 0.8738 - acc: 0.9267 - val_loss: 1.0748 - val_recall_11: 0.4286 - val_acc: 0.6739
# Epoch 73/200
# 30/30 [==============================] - 45s 2s/step - loss: 0.1344 - recall_11: 0.9117 - acc: 0.9560 - val_loss: 0.9937 - val_recall_11: 0.5000 - val_acc: 0.7319
# Epoch 74/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.1010 - recall_11: 0.9306 - acc: 0.9644 - val_loss: 1.0573 - val_recall_11: 0.5000 - val_acc: 0.6884
# Epoch 75/200
# 30/30 [==============================] - 45s 2s/step - loss: 0.0681 - recall_11: 0.9621 - acc: 0.9791 - val_loss: 1.2048 - val_recall_11: 0.5000 - val_acc: 0.7174
# Epoch 76/200
# 30/30 [==============================] - 48s 2s/step - loss: 0.0736 - recall_11: 0.9558 - acc: 0.9749 - val_loss: 1.0089 - val_recall_11: 0.4643 - val_acc: 0.7246
# Epoch 77/200
# 30/30 [==============================] - 45s 2s/step - loss: 0.0638 - recall_11: 0.9621 - acc: 0.9822 - val_loss: 1.2304 - val_recall_11: 0.5000 - val_acc: 0.7246
# Epoch 78/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.0622 - recall_11: 0.9590 - acc: 0.9791 - val_loss: 1.1026 - val_recall_11: 0.4643 - val_acc: 0.7464
# Epoch 79/200
# 30/30 [==============================] - 45s 2s/step - loss: 0.0571 - recall_11: 0.9653 - acc: 0.9832 - val_loss: 1.1814 - val_recall_11: 0.4643 - val_acc: 0.7319
# Epoch 80/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.0636 - recall_11: 0.9685 - acc: 0.9812 - val_loss: 1.1009 - val_recall_11: 0.4643 - val_acc: 0.7101
# Epoch 81/200
# 30/30 [==============================] - 45s 1s/step - loss: 0.0643 - recall_11: 0.9590 - acc: 0.9759 - val_loss: 1.3189 - val_recall_11: 0.5000 - val_acc: 0.6884
# Epoch 82/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.0710 - recall_11: 0.9558 - acc: 0.9759 - val_loss: 1.0896 - val_recall_11: 0.5000 - val_acc: 0.7246
# Epoch 83/200
# 30/30 [==============================] - 45s 1s/step - loss: 0.0512 - recall_11: 0.9748 - acc: 0.9885 - val_loss: 1.2850 - val_recall_11: 0.4643 - val_acc: 0.7174
# Epoch 84/200
# 30/30 [==============================] - 45s 2s/step - loss: 0.0502 - recall_11: 0.9748 - acc: 0.9853 - val_loss: 1.3947 - val_recall_11: 0.5000 - val_acc: 0.7101
# Epoch 85/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.0448 - recall_11: 0.9621 - acc: 0.9832 - val_loss: 1.4919 - val_recall_11: 0.5000 - val_acc: 0.6884
# Epoch 86/200
# 30/30 [==============================] - 46s 2s/step - loss: 0.0489 - recall_11: 0.9685 - acc: 0.9801 - val_loss: 1.1731 - val_recall_11: 0.4643 - val_acc: 0.7101
# Epoch 87/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.0836 - recall_11: 0.9527 - acc: 0.9770 - val_loss: 1.3740 - val_recall_11: 0.4643 - val_acc: 0.7246
# Epoch 88/200
# 30/30 [==============================] - 45s 2s/step - loss: 0.1002 - recall_11: 0.9401 - acc: 0.9654 - val_loss: 1.4802 - val_recall_11: 0.4286 - val_acc: 0.7029
# Epoch 89/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.1149 - recall_11: 0.9369 - acc: 0.9644 - val_loss: 1.2711 - val_recall_11: 0.4643 - val_acc: 0.7174
# Epoch 90/200
# 30/30 [==============================] - 45s 1s/step - loss: 0.0697 - recall_11: 0.9621 - acc: 0.9717 - val_loss: 1.1898 - val_recall_11: 0.4643 - val_acc: 0.7826
# Epoch 91/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.0494 - recall_11: 0.9685 - acc: 0.9822 - val_loss: 1.3426 - val_recall_11: 0.4286 - val_acc: 0.7536
# Epoch 92/200
# 30/30 [==============================] - 45s 2s/step - loss: 0.0734 - recall_11: 0.9495 - acc: 0.9749 - val_loss: 1.3286 - val_recall_11: 0.7500 - val_acc: 0.7391
# Epoch 93/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.0654 - recall_11: 0.9558 - acc: 0.9749 - val_loss: 1.4509 - val_recall_11: 0.4286 - val_acc: 0.7101
# Epoch 93: early stopping

# %%
history_2 = results_2.history 
plt.figure() 
plt.plot(history_2['val_loss']) 
plt.plot(history_2['loss']) 
plt.legend(['val_loss', 'loss']) 
plt.title('Loss') 
plt.xlabel('Epochs') 
plt.ylabel('Loss')
plt.show()
  
plt.figure()
plt.plot(history_2['val_recall_11'])
plt.plot(history_2['recall_11'])
plt.legend(['val_recall_11', 'recall_11'])
plt.title('Recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.show()

plt.figure()
plt.plot(history_2['val_acc'])
plt.plot(history_2['acc'])
plt.legend(['val_acc', 'acc'])
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()

# %%
second_model.evaluate(test_images,test_y)
# Out:
# 11/11 [==============================] - 4s 319ms/step - loss: 1.4262 - recall_11: 0.5258 - acc: 0.7278
# [1.4262028932571411, 0.5257731676101685, 0.7278106212615967]

# %%
second_model.save('/content/drive/MyDrive/Melanoma_Mole/Models/second_model_tf',save_format='tf')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.

# %% [markdown]
# # Third Model

# %%
# Instantiate Sequential
third_model = models.Sequential()

# Input Layer
# Consider changes number of nodes, input_shape and activation
# 64 filters, 3*3 square each stride, max pooling into 2*2 matrix
third_model.add(layers.Conv2D(128, (3,3), input_shape = (100,100,3), activation = 'relu'))
third_model.add(layers.MaxPooling2D(2,2))
third_model.add(layers.Dropout(0.3))

#Hidden Layer
third_model.add(layers.Conv2D(64, (3,3), input_shape = (100,100,3), activation = 'relu'))
third_model.add(layers.MaxPooling2D(2,2))
third_model.add(layers.Dropout(0.3))

# Dense Layers
third_model.add(layers.Flatten())
third_model.add(layers.Dense(64,activation='relu'))

third_model.add(layers.Dense(32,activation='relu'))

# Output Layer
third_model.add(layers.Dense(1, activation='sigmoid'))

# Compile
# optimizer
third_model.compile(optimizer=Adam(lr=0.0001),
                    loss='binary_crossentropy',
                    metrics=[Recall(),'acc'])

# Summary
third_model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_16 (Conv2D)          (None, 98, 98, 128)       3584
#
#  max_pooling2d_16 (MaxPoolin  (None, 49, 49, 128)      0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 49, 49, 128)       0
#
#  conv2d_17 (Conv2D)          (None, 47, 47, 64)        73792
#
#  max_pooling2d_17 (MaxPoolin  (None, 23, 23, 64)       0
#  g2D)
#
#  dropout_5 (Dropout)         (None, 23, 23, 64)        0
#
#  flatten_13 (Flatten)        (None, 33856)             0
#
#  dense_28 (Dense)            (None, 64)                2166848
#
#  dense_29 (Dense)            (None, 32)                2080
#
#  dense_30 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 2,246,337
# Trainable params: 2,246,337
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
results_3 = third_model.fit(train_images, 
                    train_y,
                    epochs=50, verbose=1, batch_size=32,
                    validation_data=(val_images,val_y),
                    callbacks=early_stop)
# Out:
# Epoch 1/50
# 30/30 [==============================] - 47s 2s/step - loss: 0.6302 - recall_13: 0.0662 - acc: 0.6555 - val_loss: 0.5989 - val_recall_13: 0.0000e+00 - val_acc: 0.7971
# Epoch 2/50
# 30/30 [==============================] - 48s 2s/step - loss: 0.6119 - recall_13: 0.0315 - acc: 0.6660 - val_loss: 0.6082 - val_recall_13: 0.1786 - val_acc: 0.8043
# Epoch 3/50
# 30/30 [==============================] - 46s 2s/step - loss: 0.5988 - recall_13: 0.0599 - acc: 0.6639 - val_loss: 0.5766 - val_recall_13: 0.0357 - val_acc: 0.7899
# Epoch 4/50
# 30/30 [==============================] - 48s 2s/step - loss: 0.5964 - recall_13: 0.0694 - acc: 0.6660 - val_loss: 0.5651 - val_recall_13: 0.0357 - val_acc: 0.7826
# Epoch 5/50
# 30/30 [==============================] - 46s 2s/step - loss: 0.5863 - recall_13: 0.0442 - acc: 0.6639 - val_loss: 0.5730 - val_recall_13: 0.2500 - val_acc: 0.8043
# Epoch 6/50
# 30/30 [==============================] - 48s 2s/step - loss: 0.5974 - recall_13: 0.1577 - acc: 0.6681 - val_loss: 0.5928 - val_recall_13: 0.0357 - val_acc: 0.8043
# Epoch 7/50
# 30/30 [==============================] - 46s 2s/step - loss: 0.5710 - recall_13: 0.0789 - acc: 0.6754 - val_loss: 0.5771 - val_recall_13: 0.2500 - val_acc: 0.8188
# Epoch 8/50
# 30/30 [==============================] - 48s 2s/step - loss: 0.5626 - recall_13: 0.2145 - acc: 0.6995 - val_loss: 0.5696 - val_recall_13: 0.2143 - val_acc: 0.8116
# Epoch 9/50
# 30/30 [==============================] - 46s 2s/step - loss: 0.5510 - recall_13: 0.2050 - acc: 0.6984 - val_loss: 0.5143 - val_recall_13: 0.3571 - val_acc: 0.7609
# Epoch 10/50
# 30/30 [==============================] - 49s 2s/step - loss: 0.5408 - recall_13: 0.3186 - acc: 0.7131 - val_loss: 0.5118 - val_recall_13: 0.1786 - val_acc: 0.8188
# Epoch 11/50
# 30/30 [==============================] - 47s 2s/step - loss: 0.5154 - recall_13: 0.3438 - acc: 0.7277 - val_loss: 0.4620 - val_recall_13: 0.3214 - val_acc: 0.7826
# Epoch 12/50
# 30/30 [==============================] - 49s 2s/step - loss: 0
50
# 30/30 [==============================] - 49s 2s/step - loss: 0.4031 - recall_13: 0.6246 - acc: 0.8168 - val_loss: 0.4653 - val_recall_13: 0.3571 - val_acc: 0.7681
# Epoch 34/50
# 30/30 [==============================] - 49s 2s/step - loss: 0.3967 - recall_13: 0.6120 - acc: 0.8188 - val_loss: 0.4167 - val_recall_13: 0.3571 - val_acc: 0.7899
# Epoch 35/50
# 30/30 [==============================] - 47s 2s/step - loss: 0.4071 - recall_13: 0.6183 - acc: 0.8094 - val_loss: 0.4207 - val_recall_13: 0.3929 - val_acc: 0.8043
# Epoch 36/50
# 30/30 [==============================] - 48s 2s/step - loss: 0.3886 - recall_13: 0.6088 - acc: 0.8220 - val_loss: 0.4174 - val_recall_13: 0.3571 - val_acc: 0.7971
# Epoch 37/50
# 30/30 [==============================] - 47s 2s/step - loss: 0.3742 - recall_13: 0.6593 - acc: 0.8450 - val_loss: 0.4624 - val_recall_13: 0.4643 - val_acc: 0.7609
# Epoch 38/50
# 30/30 [==============================] - 48s 2s/step - loss: 0.3717 - recall_13: 0.6278 - acc: 0.8314 - val_loss: 0.5057 - val_recall_13: 0.3571 - val_acc: 0.7101
# Epoch 39/50
# 30/30 [==============================] - 47s 2s/step - loss: 0.3629 - recall_13: 0.6909 - acc: 0.8450 - val_loss: 0.5326 - val_recall_13: 0.3571 - val_acc: 0.7174
# Epoch 40/50
# 30/30 [==============================] - 49s 2s/step - loss: 0.3580 - recall_13: 0.6467 - acc: 0.8450 - val_loss: 0.4551 - val_recall_13: 0.3214 - val_acc: 0.7754
# Epoch 41/50
# 30/30 [==============================] - 47s 2s/step - loss: 0.3438 - recall_13: 0.6845 - acc: 0.8503 - val_loss: 0.4701 - val_recall_13: 0.3214 - val_acc: 0.7536
# Epoch 42/50
# 30/30 [==============================] - 49s 2s/step - loss: 0.3579 - recall_13: 0.6530 - acc: 0.8429 - val_loss: 0.5012 - val_recall_13: 0.3571 - val_acc: 0.7391
# Epoch 43/50
# 30/30 [==============================] - 47s 2s/step - loss: 0.3432 - recall_13: 0.6782 - acc: 0.8461 - val_loss: 0.4685 - val_recall_13: 0.3214 - val_acc: 0.7681
# Epoch 44/50
# 30/30 [==============================] - 49s 2s/step - loss: 0.3273 - recall_13: 0.7098 - acc: 0.8607 - val_loss: 0.4448 - val_recall_13: 0.3214 - val_acc: 0.7971
# Epoch 45/50
# 30/30 [==============================] - 47s 2s/step - loss: 0.3468 - recall_13: 0.6719 - acc: 0.8398 - val_loss: 0.4678 - val_recall_13: 0.2857 - val_acc: 0.7754
# Epoch 46/50
# 30/30 [==============================] - 49s 2s/step - loss: 0.3145 - recall_13: 0.7350 - acc: 0.8733 - val_loss: 0.5284 - val_recall_13: 0.5714 - val_acc: 0.6957
# Epoch 47/50
# 30/30 [==============================] - 47s 2s/step - loss: 0.3242 - recall_13: 0.7224 - acc: 0.8628 - val_loss: 0.4267 - val_recall_13: 0.3214 - val_acc: 0.7754
# Epoch 48/50
# 30/30 [==============================] - 49s 2s/step - loss: 0.3163 - recall_13: 0.7256 - acc: 0.8754 - val_loss: 0.5215 - val_recall_13: 0.3929 - val_acc: 0.7319
# Epoch 49/50
# 30/30 [==============================] - 49s 2s/step - loss: 0.2975 - recall_13: 0.7445 - acc: 0.8702 - val_loss: 0.5035 - val_recall_13: 0.2857 - val_acc: 0.7754
# Epoch 50/50
# 30/30 [==============================] - 46s 2s/step - loss: 0.3321 - recall_13: 0.7003 - acc: 0.8513 - val_loss: 0.4659 - val_recall_13: 0.3214 - val_acc: 0.7536

# %%
history_3 = results_3.history 
plt.figure() 
plt.plot(history_3['val_loss']) 
plt.plot(history_3['loss']) 
plt.legend(['val_loss', 'loss']) 
plt.title('Loss') 
plt.xlabel('Epochs') 
plt.ylabel('Loss')
plt.show()
  
plt.figure()
plt.plot(history_3['val_recall_13'])
plt.plot(history_3['recall_13'])
plt.legend(['val_recall_13', 'recall_13'])
plt.title('Recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.show()

plt.figure()
plt.plot(history_3['val_acc'])
plt.plot(history_3['acc'])
plt.legend(['val_acc', 'acc'])
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()

# %%
third_model.evaluate(test_images,test_y)
# Out:
# 11/11 [==============================] - 5s 434ms/step - loss: 0.5074 - recall_13: 0.4330 - acc: 0.7722
# [0.5073809027671814, 0.4329896867275238, 0.7721893787384033]

# %%
third_model.save('/content/drive/MyDrive/Melanoma_Mole/Models/third_model_tf',save_format='tf')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.

# %% [markdown]
# # Fourth Model

# %%
# Instantiate Sequential
fourth_model = models.Sequential()

# Input Layer
# Consider changes number of nodes, input_shape and activation
# 64 filters, 3*3 square each stride, max pooling into 2*2 matrix
fourth_model.add(layers.Conv2D(64, (3,3), input_shape = (100,100,3), activation = 'relu'))
fourth_model.add(layers.MaxPooling2D(2,2))

# Dense Layers
fourth_model.add(layers.Flatten())
fourth_model.add(layers.Dense(32,activation='relu'))
fourth_model.add(layers.Dense(16,activation='relu'))

# Output Layer
fourth_model.add(layers.Dense(1, activation='sigmoid'))

# Compile
# optimizer
fourth_model.compile(optimizer='adam',
                    loss='binary_crossentropy',
                    metrics=[Recall(),'acc'])

# Early Stopping
early_stop = EarlyStopping(monitor='acc', min_delta=1e-8,
                           verbose=1, patience=10,
                           mode='max')
# Summary
fourth_model.summary()
# Out:
# Model: "sequential_27"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_34 (Conv2D)          (None, 98, 98, 64)        1792
#
#  max_pooling2d_34 (MaxPoolin  (None, 49, 49, 64)       0
#  g2D)
#
#  flatten_26 (Flatten)        (None, 153664)            0
#
#  dense_60 (Dense)            (None, 32)                4917280
#
#  dense_61 (Dense)            (None, 16)                528
#
#  dense_62 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 4,919,617
# Trainable params: 4,919,617
# Non-trainable params: 0
# _________________________________________________________________

# %%
results_4 = fourth_model.fit(train_images, 
                    train_y,
                    epochs=50, verbose=1, batch_size=32,
                    validation_data=(val_images,val_y),
                    callbacks=early_stop)
# Out:
# Epoch 1/50
# 30/30 [==============================] - 13s 388ms/step - loss: 1.0685 - recall_26: 0.2397 - acc: 0.6157 - val_loss: 0.5119 - val_recall_26: 0.2143 - val_acc: 0.8116
# Epoch 2/50
# 30/30 [==============================] - 13s 439ms/step - loss: 0.6162 - recall_26: 0.1956 - acc: 0.6576 - val_loss: 0.4906 - val_recall_26: 0.2500 - val_acc: 0.8043
# Epoch 3/50
# 30/30 [==============================] - 11s 367ms/step - loss: 0.5649 - recall_26: 0.2429 - acc: 0.6974 - val_loss: 0.4479 - val_recall_26: 0.1429 - val_acc: 0.8043
# Epoch 4/50
# 30/30 [==============================] - 11s 369ms/step - loss: 0.5328 - recall_26: 0.2618 - acc: 0.7173 - val_loss: 0.4613 - val_recall_26: 0.2500 - val_acc: 0.7826
# Epoch 5/50
# 30/30 [==============================] - 11s 375ms/step - loss: 0.5173 - recall_26: 0.4322 - acc: 0.7529 - val_loss: 0.4549 - val_recall_26: 0.2857 - val_acc: 0.8188
# Epoch 6/50
# 30/30 [==============================] - 11s 376ms/step - loss: 0.5038 - recall_26: 0.4227 - acc: 0.7497 - val_loss: 0.4499 - val_recall_26: 0.0714 - val_acc: 0.7971
# Epoch 7/50
# 30/30 [==============================] - 11s 371ms/step - loss: 0.4873 - recall_26: 0.4606 - acc: 0.7613 - val_loss: 0.4429 - val_recall_26: 0.2500 - val_acc: 0.7826
# Epoch 8/50
# 30/30 [==============================] - 11s 373ms/step - loss: 0.4457 - recall_26: 0.5300 - acc: 0.7853 - val_loss: 0.5879 - val_recall_26: 0.7500 - val_acc: 0.6377
# Epoch 9/50
# 30/30 [==============================] - 11s 368ms/step - loss: 0.4761 - recall_26: 0.5363 - acc: 0.7665 - val_loss: 0.6531 - val_recall_26: 0.7500 - val_acc: 0.6014
# Epoch 10/50
# 30/30 [==============================] - 11s 374ms/step - loss: 0.4245 - recall_26: 0.5804 - acc: 0.8021 - val_loss: 0.4596 - val_recall_26: 0.2143 - val_acc: 0.7971
# Epoch 11/50
# 30/30 [==============================] - 11s 372ms/step - loss: 0.4115 - recall_26: 0.5741 - acc: 0.8000 - val_loss: 0.7439 - val_recall_26: 0.6429 - val_acc: 0.5942
# Epoch 12/50
- recall_26: 1.0000 - acc: 1.0000 - val_loss: 1.2451 - val_recall_26: 0.3929 - val_acc: 0.7391
# Epoch 47/50
# 30/30 [==============================] - 11s 372ms/step - loss: 0.0048 - recall_26: 1.0000 - acc: 1.0000 - val_loss: 1.2963 - val_recall_26: 0.4286 - val_acc: 0.7391
# Epoch 48/50
# 30/30 [==============================] - 11s 378ms/step - loss: 0.0050 - recall_26: 1.0000 - acc: 1.0000 - val_loss: 1.3029 - val_recall_26: 0.4286 - val_acc: 0.7319
# Epoch 49/50
# 30/30 [==============================] - 11s 378ms/step - loss: 0.0040 - recall_26: 1.0000 - acc: 1.0000 - val_loss: 1.3045 - val_recall_26: 0.3214 - val_acc: 0.7319
# Epoch 50/50
# 30/30 [==============================] - 11s 378ms/step - loss: 0.0036 - recall_26: 1.0000 - acc: 1.0000 - val_loss: 1.3107 - val_recall_26: 0.3929 - val_acc: 0.7536

# %%
history_4 = results_4.history 
plt.figure() 
plt.plot(history_4['val_loss']) 
plt.plot(history_4['loss']) 
plt.legend(['val_loss', 'loss']) 
plt.title('Loss') 
plt.xlabel('Epochs') 
plt.ylabel('Loss')
plt.show()
  
plt.figure()
plt.plot(history_4['val_recall_26'])
plt.plot(history_4['recall_26'])
plt.legend(['val_recall_26', 'recall_26'])
plt.title('Recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.show()

plt.figure()
plt.plot(history_4['val_acc'])
plt.plot(history_4['acc'])
plt.legend(['val_acc', 'acc'])
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()

# %%
fourth_model.save('/content/drive/MyDrive/Melanoma_Mole/Models/fourth_model_tf',save_format='tf')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.

# %%
fourth_model.evaluate(test_images,test_y)
# Out:
# 11/11 [==============================] - 1s 95ms/step - loss: 1.0736 - recall_26: 0.3918 - acc: 0.7367
# [1.073632001876831, 0.39175257086753845, 0.7366864085197449]

# %% [markdown]
# # Fifth Model

# %%
# Instantiate Sequential
fifth_model = models.Sequential()

# Input Layer
# Consider changes number of nodes, input_shape and activation
# 64 filters, 3*3 square each stride, max pooling into 2*2 matrix
fifth_model.add(layers.Conv2D(128, (3,3), input_shape = (100,100,3), activation = 'relu'))
fifth_model.add(layers.MaxPooling2D(2,2))
fifth_model.add(layers.Dropout(0.3))

#Hidden Layer
#fifth_model.add(layers.Conv2D(64, (3,3), input_shape = (100,100,3), activation = 'relu'))
#fifth_model.add(layers.MaxPooling2D(2,2))
#fifth_model.add(layers.Dropout(0.3))

#Hidden Layer
#fifth_model.add(layers.Conv2D(32, (3,3), input_shape = (100,100,3), activation = 'relu'))
#fifth_model.add(layers.MaxPooling2D(2,2))
#fifth_model.add(layers.Dropout(0.3))

# Dense Layers
fifth_model.add(layers.Flatten())
fifth_model.add(layers.Dense(64,activation='relu'))

#fifth_model.add(layers.Dense(32,activation='relu'))

# Output Layer
fifth_model.add(layers.Dense(1, activation='sigmoid'))

# Compile
# optimizer
fifth_model.compile(optimizer='adam',
                    loss='binary_crossentropy',
                    metrics=[Recall(),'acc'])
# Early Stopping
early_stop = EarlyStopping(monitor='acc', min_delta=1e-8,
                           verbose=1, patience=10,
                           mode='max')
# Summary
fifth_model.summary()
# Out:
# Model: "sequential_35"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_47 (Conv2D)          (None, 98, 98, 128)       3584
#
#  max_pooling2d_47 (MaxPoolin  (None, 49, 49, 128)      0
#  g2D)
#
#  dropout_15 (Dropout)        (None, 49, 49, 128)       0
#
#  flatten_34 (Flatten)        (None, 307328)            0
#
#  dense_79 (Dense)            (None, 64)                19669056
#
#  dense_80 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 19,672,705
# Trainable params: 19,672,705
# Non-trainable params: 0
# _________________________________________________________________

# %%
results_5 = fifth_model.fit(train_images, 
                    train_y,
                    epochs=200, verbose=1, 
                    validation_data=(val_images,val_y),
                    callbacks=early_stop)
# Out:
# Epoch 1/200
# 30/30 [==============================] - 26s 819ms/step - loss: 2.1214 - recall_34: 0.3880 - acc: 0.5539 - val_loss: 0.4804 - val_recall_34: 0.0000e+00 - val_acc: 0.7971
# Epoch 2/200
# 30/30 [==============================] - 24s 800ms/step - loss: 0.5941 - recall_34: 0.0946 - acc: 0.6796 - val_loss: 0.5901 - val_recall_34: 0.4286 - val_acc: 0.7391
# Epoch 3/200
# 30/30 [==============================] - 24s 790ms/step - loss: 0.5740 - recall_34: 0.2997 - acc: 0.7058 - val_loss: 0.4555 - val_recall_34: 0.2500 - val_acc: 0.8188
# Epoch 4/200
- recall_34: 1.0000 - acc: 1.0000 - val_loss: 1.0660 - val_recall_34: 0.3929 - val_acc: 0.7536
# Epoch 51/200
# 30/30 [==============================] - 24s 815ms/step - loss: 0.0217 - recall_34: 0.9937 - acc: 0.9979 - val_loss: 1.0487 - val_recall_34: 0.3929 - val_acc: 0.7464
# Epoch 52/200
# 30/30 [==============================] - 25s 819ms/step - loss: 0.0173 - recall_34: 0.9968 - acc: 0.9990 - val_loss: 1.0818 - val_recall_34: 0.4643 - val_acc: 0.7464
# Epoch 53/200
# 30/30 [==============================] - 29s 964ms/step - loss: 0.0171 - recall_34: 1.0000 - acc: 1.0000 - val_loss: 1.0904 - val_recall_34: 0.3929 - val_acc: 0.7391
# Epoch 54/200
# 30/30 [==============================] - 25s 823ms/step - loss: 0.0162 - recall_34: 0.9968 - acc: 0.9990 - val_loss: 1.1533 - val_recall_34: 0.4643 - val_acc: 0.7464
# Epoch 55/200
# 30/30 [==============================] - 25s 822ms/step - loss: 0.0139 - recall_34: 0.9968 - acc: 0.9990 - val_loss: 1.1810 - val_recall_34: 0.3929 - val_acc: 0.7246
# Epoch 56/200
# 30/30 [==============================] - 25s 820ms/step - loss: 0.0159 - recall_34: 1.0000 - acc: 1.0000 - val_loss: 1.1289 - val_recall_34: 0.5714 - val_acc: 0.7464
# Epoch 57/200
# 30/30 [==============================] - 25s 824ms/step - loss: 0.0128 - recall_34: 1.0000 - acc: 1.0000 - val_loss: 1.2866 - val_recall_34: 0.4643 - val_acc: 0.7246
# Epoch 58/200
# 30/30 [==============================] - 25s 829ms/step - loss: 0.0123 - recall_34: 1.0000 - acc: 1.0000 - val_loss: 1.1443 - val_recall_34: 0.3929 - val_acc: 0.7391
# Epoch 59/200
# 30/30 [==============================] - 25s 820ms/step - loss: 0.0114 - recall_34: 1.0000 - acc: 1.0000 - val_loss: 1.2289 - val_recall_34: 0.5000 - val_acc: 0.7464
# Epoch 60/200
# 30/30 [==============================] - 25s 827ms/step - loss: 0.0105 - recall_34: 1.0000 - acc: 1.0000 - val_loss: 1.2260 - val_recall_34: 0.3929 - val_acc: 0.7391
# Epoch 60: early stopping

# %%
history_5 = results_5.history 
plt.figure() 
plt.plot(history_5['val_loss']) 
plt.plot(history_5['loss']) 
plt.legend(['val_loss', 'loss']) 
plt.title('Loss') 
plt.xlabel('Epochs') 
plt.ylabel('Loss')
plt.show()
  
plt.figure()
plt.plot(history_5['val_recall_34'])
plt.plot(history_5['recall_34'])
plt.legend(['val_recall_34', 'recall_34'])
plt.title('Recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.show()

plt.figure()
plt.plot(history_5['val_acc'])
plt.plot(history_5['acc'])
plt.legend(['val_acc', 'acc'])
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()

# %%
fifth_model.evaluate(test_images,test_y)
# Out:
# 11/11 [==============================] - 2s 172ms/step - loss: 1.1065 - recall_34: 0.4330 - acc: 0.7456
# [1.106487512588501, 0.4329896867275238, 0.7455621361732483]

# %%
fifth_model.save('/content/drive/MyDrive/Melanoma_Mole/Models/fourth_model_tf',save_format='tf')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.

# %% [markdown]
# # Sixth Model

# %%
datagen_2 = ImageDataGenerator(rescale=1/255,
  samplewise_center=True, 
  featurewise_std_normalization=False,
  samplewise_std_normalization=True,
  zca_whitening=False,
  )

# %%
training_generator_2 = datagen_2.flow_from_directory(
    '/content/drive/MyDrive/Melanoma_Mole/Training_Photos',
    target_size=(100, 100),
    batch_size=955,
    color_mode = 'rgb',
    class_mode='binary'
    )
                               
validation_generator_2 = datagen_2.flow_from_directory(
    '/content/drive/MyDrive/Melanoma_Mole/Validation_Photos',
    target_size=(100, 100),
    batch_size=138,
    color_mode = 'rgb',
    class_mode='binary'
    )

testing_generator_2 = datagen_2.flow_from_directory(
    '/content/drive/MyDrive/Melanoma_Mole/Testing_Photos',
    target_size=(100, 100),
    batch_size=338,
    color_mode = 'rgb',
   class_mode='binary'
   )
# Out:
# Found 9550 images belonging to 2 classes.
# Found 1382 images belonging to 2 classes.
# Found 3385 images belonging to 2 classes.

# %%
train_images_2, train_labels_2 = next(training_generator_2)
val_images_2, val_labels_2 = next(validation_generator_2)
test_images_2, test_labels_2 = next(testing_generator_2)

# %%
# Instantiate Sequential
sixth_model = models.Sequential()

# Input Layer
# Consider changes number of nodes, input_shape and activation
# 64 filters, 3*3 square each stride, max pooling into 2*2 matrix
sixth_model.add(layers.Conv2D(128, (3,3), input_shape = (100,100,3), activation = 'relu'))
sixth_model.add(layers.MaxPooling2D(2,2))
sixth_model.add(layers.Dropout(0.3))

#Hidden Layer
sixth_model.add(layers.Conv2D(64, (3,3), input_shape = (100,100,3), activation = 'relu'))
sixth_model.add(layers.MaxPooling2D(2,2))
sixth_model.add(layers.Dropout(0.3))

# Dense Layers
sixth_model.add(layers.Flatten())
sixth_model.add(layers.Dense(64,activation='relu'))

sixth_model.add(layers.Dense(32,activation='relu'))

# Output Layer
sixth_model.add(layers.Dense(1, activation='sigmoid'))

# Compile
# optimizer
sixth_model.compile(optimizer='adam',
                    loss='binary_crossentropy',
                    metrics=[Recall(),'acc'])

# Early Stopping
early_stop = EarlyStopping(monitor='acc', min_delta=1e-8,
                           verbose=1, patience=10,
                           mode='max')
# Summary
sixth_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 98, 98, 128)       3584
#
#  max_pooling2d_2 (MaxPooling  (None, 49, 49, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 49, 49, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 47, 47, 64)        73792
#
#  max_pooling2d_3 (MaxPooling  (None, 23, 23, 64)       0
#  2D)
#
#  dropout_3 (Dropout)         (None, 23, 23, 64)        0
#
#  flatten_1 (Flatten)         (None, 33856)             0
#
#  dense_3 (Dense)             (None, 64)                2166848
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2,246,337
# Trainable params: 2,246,337
# Non-trainable params: 0
# _________________________________________________________________

# %%
results_6 = sixth_model.fit(train_images_2, 
                    train_labels_2,
                    epochs=200, verbose=1, 
                    validation_data=(val_images_2,val_labels_2),
                    callbacks=early_stop)
# Out:
# Epoch 1/200
# 30/30 [==============================] - 50s 2s/step - loss: 0.6722 - recall_1: 0.8840 - acc: 0.6953 - val_loss: 0.5390 - val_recall_1: 0.8056 - val_acc: 0.7609
# Epoch 2/200
# 30/30 [==============================] - 49s 2s/step - loss: 0.5580 - recall_1: 0.8480 - acc: 0.7089 - val_loss: 0.4924 - val_recall_1: 0.8889 - val_acc: 0.8043
# Epoch 3/200
# 30/30 [==============================] - 45s 1s/step - loss: 0.5285 - recall_1: 0.8871 - acc: 0.7403 - val_loss: 0.4601 - val_recall_1: 0.9352 - val_acc: 0.8261
# Epoch 4/200
# 30/30 [==============================] - 45s 1s/step - loss: 0.5067 - recall_1: 0.8840 - acc: 0.7414 - val_loss: 0.4316 - val_recall_1: 0.8704 - val_acc: 0.7971
# Epoch 5/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.4880 - recall_1: 0.8856 - acc: 0.7571 - val_loss: 0.5160 - val_recall_1: 0.7037 - val_acc: 0.6957
# Epoch 6/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.4734 - recall_1: 0.8683 - acc: 0.7749 - val_loss: 0.5132 - val_recall_1: 0.7593 - val_acc: 0.7101
# Epoch 7/200
# 30/30 [==============================] - 45s 1s/step - loss: 0.4369 - recall_1: 0.8966 - acc: 0.7937 - val_loss: 0.4262 - val_recall_1: 0.9352 - val_acc: 0.8551
# Epoch 8/200
# 30/30 [==============================] - 45s 1s/step - loss: 0.4261 - recall_1: 0.8997 - acc: 0.8105 - val_loss: 0.4747 - val_recall_1: 0.8056 - val_acc: 0.7609
# Epoch 9/200
# 30/30 [==============================] - 51s 2s/step - loss: 0.3840 - recall_1: 0.8950 - acc: 0.8251 - val_loss: 0.5249 - val_recall_1: 0.7315 - val_acc: 0.7246
# Epoch 10/200
# 30/30 [==============================] - 48s 2s/step - loss: 0.3648 - recall_1: 0.8966 - acc: 0.8314 - val_loss: 0.5455 - val_recall_1: 0.7222 - val_acc: 0.7391
# Epoch 11/200
# 30/30 [==============================] - 45s 1s/step - loss: 0.3104 - recall_1: 0.9373 - acc: 0.8702 - val_loss: 0.5816 - val_recall_1: 0.7315 - val_acc: 0.7319
# Epoch 12/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.3093 - recall_1: 0.9169 - acc: 0.8607 - val_loss: 0.4785 - val_recall_1: 0.8241 - val_acc: 0.7826
# Epoch 13/200
# 30/30 [==============================] - 45s 1s/step - loss: 0.2580 - recall_1: 0.9232 - acc: 0.8890 - val_loss: 0.6869 - val_recall_1: 0.6667 - val_acc: 0.6957
# Epoch 14/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.2576 - recall_1: 0.9232 - acc: 0.8775 - val_loss: 0.5998 - val_recall_1: 0.7778 - val_acc: 0.7391
# Epoch 15/200
# 30/30 [==============================] - 45s 1s/step - loss: 0.2137 - recall_1: 0.9530 - acc: 0.9152 - val_loss: 0.5590 - val_recall_1: 0.7963 - val_acc: 0.7826
# Epoch 16/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.1872 - recall_1: 0.9467 - acc: 0.9298 - val_loss: 0.6375 - val_recall_1: 0.7222 - val_acc: 0.7174
# Epoch 17/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.1780 - recall_1: 0.9561 - acc: 0.9236 - val_loss: 0.7760 - val_recall_1: 0.7222 - val_acc: 0.7174
# Epoch 18/200
# 30/30 [==============================] - 45s 1s/step - loss: 0.1182 - recall_1: 0.9718 - acc: 0.9497 - val_loss: 0.8641 - val_recall_1: 0.6852 - val_acc: 0.6957
# Epoch 19/200
# 30/30 [==============================] - 45s 2s/step - loss: 0.1443 - recall_1: 0.9436 - acc: 0.9330 - val_loss: 0.6828 - val_recall_1: 0.7593 - val_acc: 0.7391
# Epoch 20/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.0986 - recall_1: 0.9734 - acc: 0.9571 - val_loss: 0.8142 - val_recall_1: 0.7500 - val_acc: 0.7319
# Epoch 21/200
# 30/30 [==============================] - 49s 2s/step - loss: 0.0911 - recall_1: 0.9765 - acc: 0.9675 - val_loss: 0.8775 - val_recall_1: 0.7685 - val_acc: 0.7174
# Epoch 22/200
# 30/30 [==============================] - 46s 2s/step - loss: 0.0979 - recall_1: 0.9734 - acc: 0.9602 - val_loss: 1.0620 - val_recall_1: 0.7037 - val_acc: 0.6957
# Epoch 23/200
# 30/30 [==============================] - 45s 2s/step - loss: 0.0898 - recall_1: 0.9671 - acc: 0.9623 - val_loss: 0.8489 - val_recall_1: 0.7593 - val_acc: 0.7391
# Epoch 24/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.0679 - recall_1: 0.9812 - acc: 0.9738 - val_loss: 0.9044 - val_recall_1: 0.7870 - val_acc: 0.7319
# Epoch 25/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.0678 - recall_1: 0.9812 - acc: 0.9749 - val_loss: 1.0712 - val_recall_1: 0.7315 - val_acc: 0.7174
# Epoch 26/200
# 30/30 [==============================] - 45s 1s/step - loss: 0.0535 - recall_1: 0.9890 - acc: 0.9801 - val_loss: 1.0179 - val_recall_1: 0.7407 - val_acc: 0.7029
# Epoch 27/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.0447 - recall_1: 0.9922 - acc: 0.9832 - val_loss: 1.1745 - val_recall_1: 0.7315 - val_acc: 0.7246
# Epoch 28/200
# 30/30 [==============================] - 45s 1s/step - loss: 0.1044 - recall_1: 0.9702 - acc: 0.9592 - val_loss: 0.9600 - val_recall_1: 0.7870 - val_acc: 0.7464
# Epoch 29/200
# 30/30 [==============================] - 49s 2s/step - loss: 0.0596 - recall_1: 0.9828 - acc: 0.9780 - val_loss: 1.0137 - val_recall_1: 0.7315 - val_acc: 0.7101
# Epoch 30/200
# 30/30 [==============================] - 44s 1s/step - loss: 0.0638 - recall_1: 0.9812 - acc: 0.9717 - val_loss: 1.1116 - val_recall_1: 0.6389 - val_acc: 0.6304
# Epoch 31/200
# 30/30 [==============================] - 50s 2s/step - loss: 0.0624 - recall_1: 0.9828 - acc: 0.9770 - val_loss: 1.0977 - val_recall_1: 0.7500 - val_acc: 0.7391
# Epoch 32/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.0414 - recall_1: 0.9922 - acc: 0.9906 - val_loss: 1.1792 - val_recall_1: 0.7037 - val_acc: 0.6957
# Epoch 33/200
# 30/30 [==============================] - 45s 1s/step - loss: 0.0299 - recall_1: 0.9937 - acc: 0.9916 - val_loss: 1.0503 - val_recall_1: 0.7593 - val_acc: 0.7174
# Epoch 34/200
# 30/30 [==============================] - 44s 1s/step - loss: 0.0755 - recall_1: 0.9796 - acc: 0.9749 - val_loss: 1.2731 - val_recall_1: 0.6852 - val_acc: 0.6739
# Epoch 35/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.0474 - recall_1: 0.9890 - acc: 0.9832 - val_loss: 1.1155 - val_recall_1: 0.7500 - val_acc: 0.7174
# Epoch 36/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.0269 - recall_1: 0.9969 - acc: 0.9937 - val_loss: 1.3522 - val_recall_1: 0.7500 - val_acc: 0.7391
# Epoch 37/200
# 30/30 [==============================] - 45s 1s/step - loss: 0.0355 - recall_1: 0.9890 - acc: 0.9843 - val_loss: 1.4242 - val_recall_1: 0.6852 - val_acc: 0.6812
# Epoch 38/200
# 30/30 [==============================] - 45s 1s/step - loss: 0.0379 - recall_1: 0.9875 - acc: 0.9832 - val_loss: 1.0480 - val_recall_1: 0.7870 - val_acc: 0.7536
# Epoch 39/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.0182 - recall_1: 0.9984 - acc: 0.9969 - val_loss: 1.4171 - val_recall_1: 0.7315 - val_acc: 0.7101
# Epoch 40/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.0233 - recall_1: 0.9922 - acc: 0.9906 - val_loss: 1.5148 - val_recall_1: 0.6481 - val_acc: 0.6667
# Epoch 41/200
# 30/30 [==============================] - 45s 1s/step - loss: 0.0305 - recall_1: 0.9890 - acc: 0.9843 - val_loss: 1.8082 - val_recall_1: 0.5833 - val_acc: 0.6159
# Epoch 42/200
# 30/30 [==============================] - 45s 1s/step - loss: 0.0168 - recall_1: 0.9953 - acc: 0.9948 - val_loss: 1.2341 - val_recall_1: 0.6852 - val_acc: 0.6739
# Epoch 43/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.0221 - recall_1: 0.9937 - acc: 0.9948 - val_loss: 1.2877 - val_recall_1: 0.7037 - val_acc: 0.6812
# Epoch 44/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.0117 - recall_1: 0.9984 - acc: 0.9979 - val_loss: 1.1508 - val_recall_1: 0.7500 - val_acc: 0.7101
# Epoch 45/200
# 30/30 [==============================] - 45s 1s/step - loss: 0.0078 - recall_1: 1.0000 - acc: 0.9979 - val_loss: 1.2336 - val_recall_1: 0.7870 - val_acc: 0.7391
# Epoch 46/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.0056 - recall_1: 1.0000 - acc: 0.9990 - val_loss: 1.2680 - val_recall_1: 0.7870 - val_acc: 0.7391
# Epoch 47/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.0060 - recall_1: 1.0000 - acc: 0.9990 - val_loss: 1.4719 - val_recall_1: 0.7037 - val_acc: 0.7029
# Epoch 48/200
# 30/30 [==============================] - 45s 1s/step - loss: 0.0060 - recall_1: 0.9984 - acc: 0.9979 - val_loss: 1.3727 - val_recall_1: 0.7778 - val_acc: 0.7464
# Epoch 49/200
# 30/30 [==============================] - 44s 1s/step - loss: 0.0198 - recall_1: 0.9969 - acc: 0.9958 - val_loss: 1.3935 - val_recall_1: 0.7222 - val_acc: 0.6957
# Epoch 50/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.0108 - recall_1: 0.9969 - acc: 0.9948 - val_loss: 1.3836 - val_recall_1: 0.7315 - val_acc: 0.7101
# Epoch 51/200
# 30/30 [==============================] - 48s 2s/step - loss: 0.0108 - recall_1: 0.9969 - acc: 0.9969 - val_loss: 1.4584 - val_recall_1: 0.7500 - val_acc: 0.7101
# Epoch 52/200
# 30/30 [==============================] - 46s 2s/step - loss: 0.0065 - recall_1: 0.9969 - acc: 0.9958 - val_loss: 1.5629 - val_recall_1: 0.7593 - val_acc: 0.7246
# Epoch 53/200
# 30/30 [==============================] - 45s 1s/step - loss: 0.0047 - recall_1: 1.0000 - acc: 0.9990 - val_loss: 1.6863 - val_recall_1: 0.7685 - val_acc: 0.7174
# Epoch 54/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.0109 - recall_1: 0.9969 - acc: 0.9958 - val_loss: 1.6517 - val_recall_1: 0.7407 - val_acc: 0.6957
# Epoch 55/200
# 30/30 [==============================] - 47s 2s/step - loss: 0.0093 - recall_1: 0.9984 - acc: 0.9969 - val_loss: 1.4397 - val_recall_1: 0.7963 - val_acc: 0.7391
# Epoch 56/200
# 30/30 [==============================] - 45s 1s/step - loss: 0.0100 - recall_1: 0.9969 - acc: 0.9969 - val_loss: 1.4841 - val_recall_1: 0.8333 - val_acc: 0.7609
# Epoch 56: early stopping

# %%
history_6 = results_6.history 
plt.figure() 
plt.plot(history_6['val_loss']) 
plt.plot(history_6['loss']) 
plt.legend(['val_loss', 'loss']) 
plt.title('Loss') 
plt.xlabel('Epochs') 
plt.ylabel('Loss')
plt.show()
  
plt.figure()
plt.plot(history_6['val_recall_1'])
plt.plot(history_6['recall_1'])
plt.legend(['val_recall_1', 'recall_1'])
plt.title('Recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.show()

plt.figure()
plt.plot(history_6['val_acc'])
plt.plot(history_6['acc'])
plt.legend(['val_acc', 'acc'])
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()

# %%
sixth = models.load_model('/content/drive/MyDrive/Melanoma_Mole/Models/sixth_model_tf')
sixth.evaluate(test_images,test_labels)
# Out:
# 106/106 [==============================] - 1s 5ms/step - loss: 1.8421 - recall_1: 0.8399 - acc: 0.7353
# [1.8421499729156494, 0.8399193286895752, 0.7353028059005737]

# %%
#sixth_model.save('/content/drive/MyDrive/Melanoma_Mole/Models/sixth_model_tf',save_format='tf')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.

# %% [markdown]
# # Seventh Model

# %%
datagen = ImageDataGenerator(rescale=1/255,
  samplewise_center=True, 
  featurewise_std_normalization=False,
  samplewise_std_normalization=True,
  rotation_range=10,  
  zoom_range = 0.1,
  )

# %%
training_generator = datagen.flow_from_directory(
    '/content/drive/MyDrive/Melanoma_Mole/Training_Photos',
    target_size=(100, 100),
    batch_size=9550,
    color_mode = 'rgb',
    class_mode='binary'
    )
                               
validation_generator = datagen.flow_from_directory(
    '/content/drive/MyDrive/Melanoma_Mole/Validation_Photos',
    target_size=(100, 100),
    batch_size=1382,
    color_mode = 'rgb',
    class_mode='binary'
    )

testing_generator = datagen.flow_from_directory(
    '/content/drive/MyDrive/Melanoma_Mole/Testing_Photos',
    target_size=(100, 100),
    batch_size=3385,
    color_mode = 'rgb',
   class_mode='binary'
   )
# Out:
# Found 9550 images belonging to 2 classes.
# Found 1382 images belonging to 2 classes.
# Found 3385 images belonging to 2 classes.

# %%
train_images, train_labels = next(training_generator)
val_images, val_labels = next(validation_generator)
test_images, test_labels = next(testing_generator)

# %%
#Saving image arrays
with open(f'/content/drive/MyDrive/Melanoma_Mole/Arrays/train_images_arrays_3.npy', 'wb') as f:
  np.save(f, train_images)
with open(f'/content/drive/MyDrive/Melanoma_Mole/Arrays/val_images_arrays_3.npy', 'wb') as f:
  np.save(f, val_images)
with open(f'/content/drive/MyDrive/Melanoma_Mole/Arrays/test_images_arrays_3.npy', 'wb') as f:
  np.save(f, test_images)

#Saving label arrays
with open('/content/drive/MyDrive/Melanoma_Mole/Arrays/train_label_arrays_3.npy', 'wb') as f:
  np.save(f, train_labels)
with open('/content/drive/MyDrive/Melanoma_Mole/Arrays/val_label_arrays_3.npy', 'wb') as f:
  np.save(f, val_labels)
with open('/content/drive/MyDrive/Melanoma_Mole/Arrays/test_label_arrays_3.npy', 'wb') as f:
  np.save(f, test_labels)

# %%
train_images = np.load('/content/drive/MyDrive/Melanoma_Mole/Arrays/train_images_arrays_3.npy')
val_images = np.load('/content/drive/MyDrive/Melanoma_Mole/Arrays/val_images_arrays_3.npy')
test_images = np.load('/content/drive/MyDrive/Melanoma_Mole/Arrays/test_images_arrays_3.npy')

train_labels = np.load('/content/drive/MyDrive/Melanoma_Mole/Arrays/train_label_arrays_3.npy')
val_labels = np.load('/content/drive/MyDrive/Melanoma_Mole/Arrays/val_label_arrays_3.npy')
test_labels = np.load('/content/drive/MyDrive/Melanoma_Mole/Arrays/test_label_arrays_3.npy')

# %%
# Instantiate Sequential
seventh_model = models.Sequential()

# Input Layer
# Consider changes number of nodes, input_shape and activation
# 64 filters, 3*3 square each stride, max pooling into 2*2 matrix
seventh_model.add(layers.Conv2D(64, (3,3), input_shape = (100,100,3), activation = 'relu'))
seventh_model.add(layers.MaxPooling2D(2,2))
seventh_model.add(layers.Dropout(0.3))

#Hidden Layer
seventh_model.add(layers.Conv2D(32, (3,3), input_shape = (100,100,3), activation = 'relu'))
seventh_model.add(layers.MaxPooling2D(2,2))
seventh_model.add(layers.Dropout(0.3))

# Dense Layers
seventh_model.add(layers.Flatten())
seventh_model.add(layers.Dense(64,activation='relu'))

seventh_model.add(layers.Dense(32,activation='relu'))

# Output Layer
seventh_model.add(layers.Dense(1, activation='sigmoid'))

# Compile
# optimizer
seventh_model.compile(optimizer='adam',
                    loss='binary_crossentropy',
                    metrics=[Recall(),'acc'])

# Early Stopping
early_stop = EarlyStopping(monitor='acc', min_delta=1e-2,
                           verbose=1, patience=5,
                           mode='max')
# Summary
seventh_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 98, 98, 64)        1792
#
#  max_pooling2d_2 (MaxPooling  (None, 49, 49, 64)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 49, 49, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 47, 47, 32)        18464
#
#  max_pooling2d_3 (MaxPooling  (None, 23, 23, 32)       0
#  2D)
#
#  dropout_3 (Dropout)         (None, 23, 23, 32)        0
#
#  flatten_1 (Flatten)         (None, 16928)             0
#
#  dense_3 (Dense)             (None, 64)                1083456
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 1,105,825
# Trainable params: 1,105,825
# Non-trainable params: 0
# _________________________________________________________________

# %%
results_7 = seventh_model.fit(train_images, 
                    train_labels,
                    epochs=300, verbose=1, batch_size=16,
                    validation_data=(val_images,val_labels),
                    callbacks=early_stop)
# Out:
# Epoch 1/300
# 597/597 [==============================] - 4s 6ms/step - loss: 0.5568 - recall_1: 0.8517 - acc: 0.7104 - val_loss: 0.5264 - val_recall_1: 0.7627 - val_acc: 0.7308
# Epoch 2/300
# 597/597 [==============================] - 3s 5ms/step - loss: 0.5197 - recall_1: 0.8587 - acc: 0.7387 - val_loss: 0.5120 - val_recall_1: 0.8369 - val_acc: 0.7728
# Epoch 3/300
# 597/597 [==============================] - 3s 5ms/step - loss: 0.4898 - recall_1: 0.8673 - acc: 0.7525 - val_loss: 0.4495 - val_recall_1: 0.8418 - val_acc: 0.7865
# Epoch 4/300
# 597/597 [==============================] - 3s 6ms/step - loss: 0.4637 - recall_1: 0.8854 - acc: 0.7728 - val_loss: 0.4735 - val_recall_1: 0.8271 - val_acc: 0.7822
# Epoch 5/300
# 597/597 [==============================] - 3s 5ms/step - loss: 0.4321 - recall_1: 0.8924 - acc: 0.7928 - val_loss: 0.4240 - val_recall_1: 0.9121 - val_acc: 0.7996
# Epoch 6/300
# 597/597 [==============================] - 3s 5ms/step - loss: 0.4098 - recall_1: 0.8910 - acc: 0.8044 - val_loss: 0.4664 - val_recall_1: 0.8184 - val_acc: 0.7836
# Epoch 7/300
# 597/597 [==============================] - 3s 5ms/step - loss: 0.3747 - recall_1: 0.8989 - acc: 0.8218 - val_loss: 0.4572 - val_recall_1: 0.8711 - val_acc: 0.7931
# Epoch 8/300
# 597/597 [==============================] - 3s 5ms/step - loss: 0.3347 - recall_1: 0.9148 - acc: 0.8498 - val_loss: 0.5104 - val_recall_1: 0.7930 - val_acc: 0.7656
# Epoch 9/300
# 597/597 [==============================] - 3s 5ms/step - loss: 0.3088 - recall_1: 0.9169 - acc: 0.8608 - val_loss: 0.5462 - val_recall_1: 0.7500 - val_acc: 0.7453
# Epoch 10/300
# 597/597 [==============================] - 3s 5ms/step - loss: 0.2702 - recall_1: 0.9309 - acc: 0.8834 - val_loss: 0.5516 - val_recall_1: 0.8232 - val_acc: 0.7771
# Epoch 11/300
# 597/597 [==============================] - 3s 5ms/step - loss: 0.2368 - recall_1: 0.9342 - acc: 0.8953 - val_loss: 0.5688 - val_recall_1: 0.8145 - val_acc: 0.7779
# Epoch 12/300
# 597/597 [==============================] - 3s 5ms/step - loss: 0.2131 - recall_1: 0.9407 - acc: 0.9063 - val_loss: 0.5342 - val_recall_1: 0.8584 - val_acc: 0.7677
# Epoch 13/300
# 597/597 [==============================] - 3s 5ms/step - loss: 0.1910 - recall_1: 0.9466 - acc: 0.9176 - val_loss: 0.6555 - val_recall_1: 0.8203 - val_acc: 0.7728
# Epoch 14/300
# 597/597 [==============================] - 3s 5ms/step - loss: 0.1708 - recall_1: 0.9541 - acc: 0.9295 - val_loss: 0.7532 - val_recall_1: 0.8213 - val_acc: 0.7641
# Epoch 15/300
# 597/597 [==============================] - 3s 5ms/step - loss: 0.1474 - recall_1: 0.9571 - acc: 0.9371 - val_loss: 0.7848 - val_recall_1: 0.8076 - val_acc: 0.7685
# Epoch 16/300
# 597/597 [==============================] - 3s 5ms/step - loss: 0.1420 - recall_1: 0.9596 - acc: 0.9421 - val_loss: 0.7757 - val_recall_1: 0.8252 - val_acc: 0.7670
# Epoch 17/300
# 597/597 [==============================] - 3s 5ms/step - loss: 0.1236 - recall_1: 0.9653 - acc: 0.9501 - val_loss: 0.8314 - val_recall_1: 0.8213 - val_acc: 0.7685
# Epoch 18/300
# 597/597 [==============================] - 3s 5ms/step - loss: 0.1274 - recall_1: 0.9639 - acc: 0.9483 - val_loss: 1.0319 - val_recall_1: 0.7744 - val_acc: 0.7518
# Epoch 19/300
# 597/597 [==============================] - 3s 5ms/step - loss: 0.1097 - recall_1: 0.9700 - acc: 0.9560 - val_loss: 0.8991 - val_recall_1: 0.8047 - val_acc: 0.7619
# Epoch 20/300
# 597/597 [==============================] - 3s 5ms/step - loss: 0.1034 - recall_1: 0.9727 - acc: 0.9616 - val_loss: 0.8407 - val_recall_1: 0.8428 - val_acc: 0.7822
# Epoch 21/300
# 597/597 [==============================] - 3s 5ms/step - loss: 0.0827 - recall_1: 0.9776 - acc: 0.9680 - val_loss: 1.0214 - val_recall_1: 0.8242 - val_acc: 0.7706
# Epoch 22/300
# 597/597 [==============================] - 3s 5ms/step - loss: 0.0930 - recall_1: 0.9741 - acc: 0.9652 - val_loss: 0.9522 - val_recall_1: 0.8271 - val_acc: 0.7706
# Epoch 23/300
# 597/597 [==============================] - 3s 5ms/step - loss: 0.0832 - recall_1: 0.9758 - acc: 0.9662 - val_loss: 0.9129 - val_recall_1: 0.8486 - val_acc: 0.7865
# Epoch 24/300
# 597/597 [==============================] - 3s 5ms/step - loss: 0.0830 - recall_1: 0.9763 - acc: 0.9685 - val_loss: 0.9853 - val_recall_1: 0.7939 - val_acc: 0.7598
# Epoch 25/300
# 597/597 [==============================] - 3s 5ms/step - loss: 0.0686 - recall_1: 0.9803 - acc: 0.9745 - val_loss: 1.0234 - val_recall_1: 0.8604 - val_acc: 0.7822
# Epoch 26/300
# 597/597 [==============================] - 3s 5ms/step - loss: 0.0822 - recall_1: 0.9771 - acc: 0.9685 - val_loss: 1.0246 - val_recall_1: 0.8340 - val_acc: 0.7750
# Epoch 26: early stopping

# %%
seventh_model.save('/content/drive/MyDrive/Melanoma_Mole/Models/seventh_model_tf',save_format='tf')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.

# %%
history_7 = results_7.history 
plt.figure() 
plt.plot(history_7['val_loss']) 
plt.plot(history_7['loss']) 
plt.legend(['val_loss', 'loss']) 
plt.title('Loss') 
plt.xlabel('Epochs') 
plt.ylabel('Loss')
plt.show()
  
plt.figure()
plt.plot(history_7['val_recall_1'])
plt.plot(history_7['recall_1'])
plt.legend(['Validation','Training'])
plt.title('Recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.savefig('/content/drive/MyDrive/Moles/Photos/Recall_7.jpg');
plt.show()

plt.figure()
plt.plot(history_7['val_acc'])
plt.plot(history_7['acc'])
plt.legend(['Validation', 'Training'])
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.savefig('/content/drive/MyDrive/Moles/Photos/Accuracy_7.jpg');
plt.show()

# %%
loss, recall, acc = seventh_model.evaluate(test_images,test_labels)
# Out:
# 106/106 [==============================] - 0s 4ms/step - loss: 1.0288 - recall_1: 0.8387 - acc: 0.7767

# %%
recall , acc
# Out:
# (0.8387096524238586, 0.77666175365448)

# %%
#seventh = models.load_model('/content/drive/MyDrive/Melanoma_Mole/Models/seventh_model_tf')

# %% [markdown]
# # Eighth Model

# %%
datagen = ImageDataGenerator(rescale=1/255,
  samplewise_center=True, 
  featurewise_std_normalization=False,
  samplewise_std_normalization=True,
  rotation_range=10,  
  zoom_range = 0.1,
  horizontal_flip=True,
  vertical_flip=True
  )

# %%
training_generator = datagen.flow_from_directory(
    '/content/drive/MyDrive/Melanoma_Mole/Training_Photos',
    target_size=(100, 100),
    batch_size=9550,
    color_mode = 'rgb',
    class_mode='binary'
    )
                               
validation_generator = datagen.flow_from_directory(
    '/content/drive/MyDrive/Melanoma_Mole/Validation_Photos',
    target_size=(100, 100),
    batch_size=1382,
    color_mode = 'rgb',
    class_mode='binary'
    )

testing_generator = datagen.flow_from_directory(
    '/content/drive/MyDrive/Melanoma_Mole/Testing_Photos',
    target_size=(100, 100),
    batch_size=3385,
    color_mode = 'rgb',
   class_mode='binary'
   )
# Out:
# Found 9550 images belonging to 2 classes.
# Found 1382 images belonging to 2 classes.
# Found 3385 images belonging to 2 classes.

# %%
train_images, train_labels = next(training_generator)
val_images, val_labels = next(validation_generator)
test_images, test_labels = next(testing_generator)

# %%
#Saving image arrays
#with open(f'/content/drive/MyDrive/Melanoma_Mole/Arrays/train_images_arrays_4.npy', 'wb') as f:
#  np.save(f, train_images)
#with open(f'/content/drive/MyDrive/Melanoma_Mole/Arrays/val_images_arrays_4.npy', 'wb') as f:
#  np.save(f, val_images)
#with open(f'/content/drive/MyDrive/Melanoma_Mole/Arrays/test_images_arrays_4.npy', 'wb') as f:
#  np.save(f, test_images)

#Saving label arrays
#with open('/content/drive/MyDrive/Melanoma_Mole/Arrays/train_label_arrays_4.npy', 'wb') as f:
#  np.save(f, train_labels)
#with open('/content/drive/MyDrive/Melanoma_Mole/Arrays/val_label_arrays_4.npy', 'wb') as f:
#  np.save(f, val_labels)
#with open('/content/drive/MyDrive/Melanoma_Mole/Arrays/test_label_arrays_4.npy', 'wb') as f:
#  np.save(f, test_labels)

# %%
train_images = np.load('/content/drive/MyDrive/Melanoma_Mole/Arrays/train_images_arrays_4.npy')
val_images = np.load('/content/drive/MyDrive/Melanoma_Mole/Arrays/val_images_arrays_4.npy')
test_images = np.load('/content/drive/MyDrive/Melanoma_Mole/Arrays/test_images_arrays_4.npy')

train_labels = np.load('/content/drive/MyDrive/Melanoma_Mole/Arrays/train_label_arrays_4.npy')
val_labels = np.load('/content/drive/MyDrive/Melanoma_Mole/Arrays/val_label_arrays_4.npy')
test_labels = np.load('/content/drive/MyDrive/Melanoma_Mole/Arrays/test_label_arrays_4.npy')

# %%
# Instantiate Sequential
eighth_model = models.Sequential()

# Input Layer
# Consider changes number of nodes, input_shape and activation
# 64 filters, 3*3 square each stride, max pooling into 2*2 matrix
eighth_model.add(layers.Conv2D(128, (3,3), input_shape = (100,100,3), activation = 'relu'))
eighth_model.add(layers.MaxPooling2D(2,2))
eighth_model.add(layers.Dropout(0.3))

#Hidden Layer
eighth_model.add(layers.Conv2D(64, (3,3), input_shape = (100,100,3), activation = 'relu'))
eighth_model.add(layers.MaxPooling2D(2,2))
eighth_model.add(layers.Dropout(0.3))

# Dense Layers
eighth_model.add(layers.Flatten())
eighth_model.add(layers.Dense(128,activation='relu'))
eighth_model.add(layers.Dense(64,activation='relu'))

eighth_model.add(layers.Dense(32,activation='relu'))

# Output Layer
eighth_model.add(layers.Dense(1, activation='sigmoid'))

# Compile
# optimizer
eighth_model.compile(optimizer=Adam(learning_rate=0.0001),
                    loss='binary_crossentropy',
                    metrics=[Recall(),'acc'])

# Early Stopping
early_stop = EarlyStopping(monitor='acc', min_delta=1e-5,
                           verbose=1, patience=5,
                           mode='max')
# Summary
eighth_model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 98, 98, 128)       3584
#
#  max_pooling2d_11 (MaxPoolin  (None, 49, 49, 128)      0
#  g2D)
#
#  dropout_11 (Dropout)        (None, 49, 49, 128)       0
#
#  conv2d_13 (Conv2D)          (None, 47, 47, 64)        73792
#
#  max_pooling2d_12 (MaxPoolin  (None, 23, 23, 64)       0
#  g2D)
#
#  dropout_12 (Dropout)        (None, 23, 23, 64)        0
#
#  flatten_5 (Flatten)         (None, 33856)             0
#
#  dense_13 (Dense)            (None, 128)               4333696
#
#  dense_14 (Dense)            (None, 64)                8256
#
#  dense_15 (Dense)            (None, 32)                2080
#
#  dense_16 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 4,421,441
# Trainable params: 4,421,441
# Non-trainable params: 0
# _________________________________________________________________

# %%
results_8 = eighth_model.fit(train_images, 
                    train_labels,
                    epochs=300, verbose=1, batch_size=16,
                    validation_data=(val_images,val_labels),
                    callbacks=early_stop)
# Out:
# Epoch 1/300
# 597/597 [==============================] - 15s 7ms/step - loss: 0.5428 - recall_4: 0.8552 - acc: 0.7184 - val_loss: 0.5235 - val_recall_4: 0.8926 - val_acc: 0.7779
# Epoch 2/300
# 597/597 [==============================] - 4s 6ms/step - loss: 0.5034 - recall_4: 0.8749 - acc: 0.7441 - val_loss: 0.5058 - val_recall_4: 0.8955 - val_acc: 0.7916
# Epoch 3/300
# 597/597 [==============================] - 4s 6ms/step - loss: 0
300
# 597/597 [==============================] - 4s 6ms/step - loss: 0.0157 - recall_4: 0.9962 - acc: 0.9943 - val_loss: 1.2252 - val_recall_4: 0.8398 - val_acc: 0.7793
# Epoch 46/300
# 597/597 [==============================] - 4s 6ms/step - loss: 0.0190 - recall_4: 0.9949 - acc: 0.9933 - val_loss: 1.2383 - val_recall_4: 0.8613 - val_acc: 0.7959
# Epoch 47/300
# 597/597 [==============================] - 4s 6ms/step - loss: 0.0130 - recall_4: 0.9968 - acc: 0.9955 - val_loss: 1.2900 - val_recall_4: 0.8555 - val_acc: 0.7887
# Epoch 48/300
# 597/597 [==============================] - 4s 6ms/step - loss: 0.0085 - recall_4: 0.9983 - acc: 0.9977 - val_loss: 1.3737 - val_recall_4: 0.8359 - val_acc: 0.7829
# Epoch 49/300
# 597/597 [==============================] - 4s 6ms/step - loss: 0.0211 - recall_4: 0.9948 - acc: 0.9923 - val_loss: 1.4086 - val_recall_4: 0.7910 - val_acc: 0.7547
# Epoch 50/300
# 597/597 [==============================] - 4s 6ms/step - loss: 0.0187 - recall_4: 0.9948 - acc: 0.9927 - val_loss: 1.3141 - val_recall_4: 0.8701 - val_acc: 0.7865
# Epoch 51/300
# 597/597 [==============================] - 4s 6ms/step - loss: 0.0186 - recall_4: 0.9957 - acc: 0.9932 - val_loss: 1.3543 - val_recall_4: 0.8389 - val_acc: 0.7822
# Epoch 52/300
# 597/597 [==============================] - 4s 6ms/step - loss: 0.0110 - recall_4: 0.9975 - acc: 0.9961 - val_loss: 1.3538 - val_recall_4: 0.8672 - val_acc: 0.7873
# Epoch 53/300
# 597/597 [==============================] - 4s 6ms/step - loss: 0.0168 - recall_4: 0.9959 - acc: 0.9943 - val_loss: 1.2392 - val_recall_4: 0.8564 - val_acc: 0.7836
# Epoch 53: early stopping

# %%
history_8 = results_8.history 
plt.figure() 
plt.plot(history_8['val_loss'])
plt.plot(history_8['loss']) 
plt.legend(['val_loss', 'loss']) 
plt.title('Loss') 
plt.xlabel('Epochs') 
plt.ylabel('Loss')
plt.show()
  
plt.figure()
plt.plot(history_8['val_recall_4'])
plt.plot(history_8['recall_4'])
plt.legend(['Validation','Training'])
plt.title('Recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.savefig('/content/drive/MyDrive/Moles/Photos/Recall.jpg');
plt.show()

plt.figure()
plt.plot(history_8['val_acc'])
plt.plot(history_8['acc'])
plt.legend(['Validation', 'Training'])
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.savefig('/content/drive/MyDrive/Moles/Photos/Accuracy.jpg');
plt.show()

# %%
loss, recall, acc = eighth_model.evaluate(test_images,test_labels)
# Out:
# 106/106 [==============================] - 1s 5ms/step - loss: 1.0007 - recall_3: 0.8133 - acc: 0.7622

# %%
print(recall, acc)
# Out:
# 0.813306450843811 0.7621861100196838

# %% [markdown]
# # Evaluation

# %% [markdown]
# The final model's results are displayed below.
#
#   > **Recall**: 83.9%
#
#   > **Accuracy**: 77.7%

# %% [markdown]
# ## Conclusions

# %% [markdown]
# **Model Performance**
#
# While the results did improve throughout the modeling process once significant augmentations were applied, with the seventh model displaying the best balance of recall and accuracy, the model still could be improved. Ultimately, I would have liked to try applying different combinations of augmentations but the sheer size of the dataset limited some of those capabilities.
#
# **Model Value and Limitations**
#
# Even though the model could still be improved, I do believe the idea has significant clinical value. As the dermatolgoist is evaluating any lesion, they could use not only the dermatoscopic view but the algorithm as an aide in their diagnosis.
#
# Implementing the model on a larger, clinical scale requires much more complex image classification as there are multiple types of skin cancers and hundreds of different types of lesions. As well, this model only takes into account simple photos, where there is clearly one defined lesion, and does not encompass the possible complexities of clinical evaluation.

# %% [markdown]
# ## Next Steps

# %% [markdown]
# - Be able to compound image evaluation with important factors like sex, age, body location and past skin cancer history
#
# - Only a subset of diagnoses analysed
#
# - Can only handle simple photos with one lesion in the area
